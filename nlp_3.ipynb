# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install wordcloud
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
y = [1,2,5,7,4,2,1]
plt.plot(y)

# %%
plt.plot(y, 'r o')

# %%
plt.plot(y, 'ro-')

# %%
y2 = [1,2,4,7,5,2,1]
y3 = [6,6,6,0,6,6,6]

# %%
plt.plot(
    y, 'r-',
    y2, 'go-',
    y3, 'b'
  )

# %%
x = [5,6,7,8,9,10,30]
plt.plot(x, y, 'ro-')

# %% [markdown]
# HISTOGRAM

# %%
a = [1,3,2,1,1,1,1,2,2,3,1,1]
plt.hist(a)
# Out:
# (array([7., 0., 0., 0., 0., 3., 0., 0., 0., 2.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
kalimat = "aku suka ayam ayam ayam suka aku suka suka aku ayam aku ayam"
uhm = kalimat.split()
plt.hist(uhm)
# Out:
# (array([4., 0., 0., 0., 0., 4., 0., 0., 0., 5.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
ah = len(set(kalimat.split()))
ah
# Out:
# 3

# %%
ah = set(y)
len(ah)
# Out:
# 5

# %%
kalimat = "aku aku aku ayam ayam ayam ayam ayam suka suka suka suka suka suka"
kampus  = Counter(kalimat.split( ))
kampus
# Out:
# Counter({'aku': 3, 'ayam': 5, 'suka': 6})

# %%
kampus.keys()
# Out:
# dict_keys(['aku', 'ayam', 'suka'])

# %%
kampus.values()
# Out:
# dict_values([3, 5, 6])

# %%
plt.bar(kampus.keys(), kampus.values())
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar([10,20,30], [100,10,50])
# Out:
# <BarContainer object of 3 artists>

# %%
paragraph = 'Monyet adalah istilah untuk semua anggota primata yang bukan prosimia ("pra-kera", seperti lemur dan tarsius) atau kera, baik yang tinggal di Dunia Lama maupun Dunia Baru. Hingga saat ini dikenal 264 jenis monyet yang hidup di dunia. Tidak seperti kera, monyet biasanya berekor dan berukuran lebih kecil. Monyet diketahui dapat belajar dan menggunakan alat untuk membantunya dalam mendapatkan makanan.'
paragraph
# Out:
# 'Monyet adalah istilah untuk semua anggota primata yang bukan prosimia ("pra-kera", seperti lemur dan tarsius) atau kera, baik yang tinggal di Dunia Lama maupun Dunia Baru. Hingga saat ini dikenal 264 jenis monyet yang hidup di dunia. Tidak seperti kera, monyet biasanya berekor dan berukuran lebih kecil. Monyet diketahui dapat belajar dan menggunakan alat untuk membantunya dalam mendapatkan makanan.'

# %%
ah = WordCloud()
plt.imshow(ah.generate(paragraph))

# %%
klmt = 'Babi adalah sejenis hewan ungulata yang bermoncong panjang dan berhidung lemper dan merupakan hewan yang aslinya berasal dari Eurasia. Babi merupakan omnivora yang berarti mereka mengonsumsi daging maupun tumbuh-tumbuhan. Selain itu, babi termasuk salah satu mamalia yang paling cerdas, dan dilaporkan lebih pintar dan mudah dipelihara dibandingkan dengan anjing dan kucing.'
klmt
# Out:
# 'Babi adalah sejenis hewan ungulata yang bermoncong panjang dan berhidung lemper dan merupakan hewan yang aslinya berasal dari Eurasia. Babi merupakan omnivora yang berarti mereka mengonsumsi daging maupun tumbuh-tumbuhan. Selain itu, babi termasuk salah satu mamalia yang paling cerdas, dan dilaporkan lebih pintar dan mudah dipelihara dibandingkan dengan anjing dan kucing.'

# %%
ah = WordCloud()
plt.imshow(ah.generate(klmt))

# %%
uhm = lambda ah: ah+10
uhm(2)
# Out:
# 12

# %%
itu = [(ini, kampus[ini]) for ini in kampus]
itu
# Out:
# [('aku', 3), ('ayam', 5), ('suka', 6)]

# %%
itu.sort(key = lambda x :x[1])
itu
# Out:
# [('aku', 3), ('ayam', 5), ('suka', 6)]

# %%
import re

# %%
kalimat = 'Vladimir Lenin adalah tokoh revolusioner komunis, politikus, dan penggagas teori politik berkebangsaan Rusia. Ia menjabat sebagai pemimpin RSFS Rusia sejak tahun 1917, lalu Perdana Menteri Uni Soviet sejak tahun 1922 hingga kematiannya.'
O = re.findall(r'\w{4}', kalimat)
O
# Out:
# ['Vlad',
#  'imir',
#  'Leni',
#  'adal',
#  'toko',
#  'revo',
#  'lusi',
#  'oner',
#  'komu',
#  'poli',
#  'tiku',
#  'peng',
#  'gaga',
#  'teor',
#  'poli',
#  'berk',
#  'eban',
#  'gsaa',
#  'Rusi',
#  'menj',
#  'abat',
#  'seba',
#  'pemi',
#  'mpin',
#  'RSFS',
#  'Rusi',
#  'seja',
#  'tahu',
#  '1917',
#  'lalu',
#  'Perd',
#  'Ment',
#  'Sovi',
#  'seja',
#  'tahu',
#  '1922',
#  'hing',
#  'kema',
#  'tian']

# %%
H = re.findall(r'[A-Z]\w+', kalimat)
H
# Out:
# ['Vladimir',
#  'Lenin',
#  'Rusia',
#  'Ia',
#  'RSFS',
#  'Rusia',
#  'Perdana',
#  'Menteri',
#  'Uni',
#  'Soviet']

# %%
# !pip install scikit-learn
# Out:
# ^C

# %%
M = re.findall(r'(?<=me)\w+(?=kan)', paragraph)
M
# Out:
# ['ngguna', 'ndapat']
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 7.5/7.5 MB 133.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 40.1/40.1 MB 288.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 298.0/298.0 KB 383.6 kB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 81.8 kB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-uninstall-uo1_e0m_\\pip.exe'
# Consider using the `--user` option or check the permissions.
